# %% [markdown]
# # Exercícios
#
# #### Pandas II
#
# ---
#
# <img src="https://selecao.letscode.com.br/favicon.png" width="40px" style="position: absolute; top: 0px; right: 40px; border-radius: 5px;" />

# %% [markdown]
# ### Para entregar! 🔥

# %% [markdown]
# **1. O arquivo `avocado.csv` consiste em um dataset que contém dados sobre vendas de abacates (*avocado*, em inglês) em diversas regiões dos Estados Unidos. Essa dataset contém as seguintes colunas:**
#
# - `Date` - a data da observação
# - `AveragePrice` - o preço médio de um único abacate
# - `year` - o ano
# - `region` - a cidade ou região da observação
# - `Total Volume` - volume total de abacates vendidos
#
# Além das informações acima, contidas no arquivo `avocado.csv`, o tipo do abacate (convencional ou orgânico) também seria uma informação importante para a sua análise. Suponhamos que você conseguiu essas informações para cada uma das observações do arquivo `avocado.csv`, na mesma ordem, e salvou-as no arquivo `avocado_type.csv`. **Portanto, tudo o que você precisa é juntar esses dois arquivos em um mesmo DataFrame. E, em seguida, salve-o em um arquivo csv.**
#
# PS. Caso queira criar uma Series com os dados aleatórios para o tipo de abacate, utilize o código abaixo:
#
# ```py
# tipos = pd.Series(np.random.randint(0, 2, df_avocado.shape[0]))
# tipos = tipos.map({0: 'convencional', 1:'orgânico'})
# ```
#
# > [Clique aqui](https://s3-sa-east-1.amazonaws.com/lcpi/45e500a1-4a2b-4cfe-8b6c-1ff831d74d87.csv) para fazer o download do dataset `avocado.csv`.
#
# > [Clique aqui](https://s3-sa-east-1.amazonaws.com/lcpi/8529cc1b-7fd3-40f1-994d-fc11f32fdf5d.csv) para fazer o download do dataset `avocado_type.csv`.

# %%
import pandas as pd 

avocado = pd.read_csv('avocado.csv')
avocado_type = pd.read_csv('avocado_type.csv')
avocado_with_type = pd.concat([avocado, avocado_type], axis=1)

avocado_with_type
# Out:
#              Date  AveragePrice  Total Volume  year            region  \
# 0      2015-12-27          1.33      64236.62  2015            Albany
# 1      2015-12-20          1.35      54876.98  2015            Albany
# 2      2015-12-13          0.93     118220.22  2015            Albany
# 3      2015-12-06          1.08      78992.15  2015            Albany
# 4      2015-11-29          1.28      51039.60  2015            Albany
# ...           ...           ...           ...   ...               ...
# 18244  2018-02-04          1.63      17074.83  2018  WestTexNewMexico
# 18245  2018-01-28          1.71      13888.04  2018  WestTexNewMexico
# 18246  2018-01-21          1.87      13766.76  2018  WestTexNewMexico
# 18247  2018-01-14          1.93      16205.22  2018  WestTexNewMexico
# 18248  2018-01-07          1.62      17489.58  2018  WestTexNewMexico
#
#                type
# 0      conventional
# 1      conventional
# 2      conventional
# 3      conventional
# ...

# %% [markdown]
# **2. Carregue o arquivo csv que você salvou na questão anterior e, em seguida, obtenha o que é solicitado nos itens elencados abaixo:**
#
# (a) A quantidade de abacates do tipo convecional e do tipo orgânico.
# (b) A quantidade de registros (linhas) de abacates vendidos para cada região.
# (c) Para que todos os labels das colunas fiquem padronizados, renomeie aqueles que estão iniciando em letra minúscula para que iniciem em letra maiúscula.
# (d) Uma vez que você já possui uma coluna com a data, remova a coluna que apresenta o ano.

# %%
avocado_conventional = avocado_with_type[avocado_with_type.type == 'conventional']
quantity_avocado_conventional = avocado_conventional['type'].count()

avocado_organic = avocado_with_type[avocado_with_type.type == 'organic']
quantity_avocado_organic = avocado_organic['type'].count()

print(f'O dataset contêm {quantity_avocado_conventional} avocados convecionais e {quantity_avocado_organic} avocados orgânicos.')
# Out:
# O dataset contêm 9126 avocados convecionais e 9123 avocados orgânicos.

# %%
avocado_group_by_region = avocado_with_type.groupby('region').count()
avocado_group_by_region = avocado_group_by_region.drop(['Date','AveragePrice','Total Volume','year'], axis = 1)
avocado_group_by_region.columns = ['Count']
avocado_group_by_region
# Out:
#                      Count
# region
# Albany                 338
# Atlanta                338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# Midsouth               338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# ...

# %%
avocado_with_type.columns = ['Date', 'Average Price', 'Total Volume', 'Year', 'Region', 'Type']
avocado_with_type
# Out:
#              Date  Average Price  Total Volume  Year            Region  \
# 0      2015-12-27           1.33      64236.62  2015            Albany
# 1      2015-12-20           1.35      54876.98  2015            Albany
# 2      2015-12-13           0.93     118220.22  2015            Albany
# 3      2015-12-06           1.08      78992.15  2015            Albany
# 4      2015-11-29           1.28      51039.60  2015            Albany
# ...           ...            ...           ...   ...               ...
# 18244  2018-02-04           1.63      17074.83  2018  WestTexNewMexico
# 18245  2018-01-28           1.71      13888.04  2018  WestTexNewMexico
# 18246  2018-01-21           1.87      13766.76  2018  WestTexNewMexico
# 18247  2018-01-14           1.93      16205.22  2018  WestTexNewMexico
# 18248  2018-01-07           1.62      17489.58  2018  WestTexNewMexico
#
#                Type
# 0      conventional
# 1      conventional
# 2      conventional
# 3      conventional
# ...

# %%
avocado_with_type.drop(['Year'], axis = 1, inplace= True)
avocado_with_type
# Out:
#              Date  Average Price  Total Volume            Region          Type
# 0      2015-12-27           1.33      64236.62            Albany  conventional
# 1      2015-12-20           1.35      54876.98            Albany  conventional
# 2      2015-12-13           0.93     118220.22            Albany  conventional
# 3      2015-12-06           1.08      78992.15            Albany  conventional
# 4      2015-11-29           1.28      51039.60            Albany  conventional
# ...           ...            ...           ...               ...           ...
# 18244  2018-02-04           1.63      17074.83  WestTexNewMexico       organic
# 18245  2018-01-28           1.71      13888.04  WestTexNewMexico       organic
# 18246  2018-01-21           1.87      13766.76  WestTexNewMexico       organic
# 18247  2018-01-14           1.93      16205.22  WestTexNewMexico       organic
# 18248  2018-01-07           1.62      17489.58  WestTexNewMexico       organic
#
# ...

# %% [markdown]
# **3. Carregue, em um objeto DataFrame, o mesmo dataset que você salvou na questão Q1, agrupe os dados do DF pelo tipo do abacate e, em seguida, obtenha:**
#
# (a) A volume total de abacates vendidos para cada tipo.
# (b) O preço médio dos abacates vendidos para cada tipo.

# %%
import pandas as pd 

avocado = pd.read_csv('avocado.csv')
avocado_type = pd.read_csv('avocado_type.csv')
avocado_with_type = pd.concat([avocado, avocado_type], axis=1)

avocado_with_type_gruped_by_type = avocado_with_type.groupby('type').mean()
avocado_with_type_gruped_by_type
# Out:
#               AveragePrice  Total Volume         year
# type
# conventional      1.158040  1.653213e+06  2016.147929
# organic           1.653999  4.781121e+04  2016.147868

# %%
#Agrupando e calculando a média e contando as ocorrências
avocado_with_type_gruped_by_type = avocado_with_type.groupby('type')
avocado_with_type_gruped_by_type = avocado_with_type_gruped_by_type.count()
mean = avocado_with_type.groupby('type').mean()

#Removendo colunas desnecessárias
mean.drop(['Total Volume', 'year'],axis = 1, inplace = True)
avocado_with_type_gruped_by_type.drop(['Date','AveragePrice','Total Volume', 'year'],axis = 1, inplace = True)

#Renomeando coluna
avocado_with_type_gruped_by_type.columns = ['Count']

#Concatenando os dois dataframes
avocado_with_type_gruped_by_type = pd.concat([mean, avocado_with_type_gruped_by_type], axis = 1)
avocado_with_type_gruped_by_type
# Out:
#               AveragePrice  Count
# type
# conventional      1.158040   9126
# organic           1.653999   9123

# %% [markdown]
# **4. O arquivo `googleplaystore.csv` é um dataset que contém diversas informações sobre aplicativos disponíveis para download na Google Play Store. Logo após, verifique se existem dados duplicados e/ou ausentes nesse dataset.**
#
# Caso existam dados duplicados, remova-os. Caso existam dados ausentes, você pode removê-los ou pensar em alguma maneira de preenchê-los.
#
# > [Clique aqui](https://s3-sa-east-1.amazonaws.com/lcpi/e1c2115b-1725-4525-9fd5-0ce57fb5c408.csv) para fazer o download do dataset.

# %%
def show_nan_stats(df):
  print('>> VALORES ABSOLUTOS <<')
  print(df.isnull().sum(), '\n')
  
  print('>> VALORES PERCENTUAIS <<')
  print(df.isnull().sum() / df.shape[0] * 100)

google_play_store = pd.read_csv('googleplaystore.csv')
show_nan_stats(google_play_store)

google_play_store.drop_duplicates(ignore_index=True, inplace = True)
google_play_store.dropna()
# Out:
# >> VALORES ABSOLUTOS <<
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
#
# >> VALORES PERCENTUAIS <<
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# ...

# %% [markdown]
# **5. O arquivo `houses_to_rent.csv` consiste em um dataset que contém dados sobre casas para alugar no Brasil. Carregue-o em um objeto DataFrame e verifique os dados contidos nas colunas desse DF (você pode utilizar os métodos `head`, `tail` e `info`). Logo após, verifique se existem dados duplicados e/ou ausentes nesse dataset.**
#
# Caso existam dados duplicados, remova-os. Caso existam dados ausentes, você pode removê-los ou pensar em alguma maneira de preenchê-los.
#
# > [Clique aqui](https://s3-sa-east-1.amazonaws.com/lcpi/bc1625bb-909a-4a15-8107-6e4047ec6cd4.csv) para fazer o download do dataset.

# %%
houses_to_hent = pd.read_csv('houses_to_rent.csv')
show_nan_stats(houses_to_hent) #Não há nenhum dado ausente

houses_to_hent[houses_to_hent.duplicated()]

houses_to_hent.drop_duplicates(ignore_index=True, inplace = True)
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 244      Porto Alegre    47      1         1               1     1  not acept
# 920    Belo Horizonte    40      1         1               1     2  not acept
# 1060        São Paulo   136      3         3               3    13      acept
# 1064        São Paulo    20      1         1               0     5      acept
# 1108         Campinas   184      4         3               4     -      acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10560    Porto Alegre    40      1         1               1     9  not acept
# 10569  Belo Horizonte    20      1         1               1     -      acept
# 10623    Porto Alegre    47      1         1               1     1  not acept
# 10640       São Paulo    27      1         1               0     5  not acept
# 10641  Belo Horizonte    58      2         2               1     5      acept
#
# ...

# %% [markdown]
# ---
#
# ### Para evoluir! 🚀

# %% [markdown]
# **01. Em um concurso público foram contabilizados os números de pessoas inscritas (até a data inicialmente estabelecida para a inscrição) segundo os níveis de escolaridade: fundamental completo, médio completo, superior completo e pós-graduação completa. Segue abaixo a tabela com os valores observados.**
#
# Nível de escolaridade | Inscritos
# :-------------------: | :-------:
# Fundamental completo  | 451
# Médio completo        | 627
# Superior completo     | 292
# Pós-graduação completa| 95
#
# Com base na tabela acima, crie uma Series com esses valores e calcule:
#
# (a) O número total de inscritos
# (b) Número inscritos que possuem, pelo menos, o superior completo.
# (c) Suponha que a inscrição foi prorrogada e, com isso, foi obtido um número adicional de inscrições: 68, 93, 22 e 0 inscritos a mais em cada uma das categorias de escolaridade apresentados na tabela acima (na mesma ordem). Assim, crie uma nova Series com esses valores.
# (d) Utilizando as duas Series que você tem, calcule o número total de inscritos após a prorrogação do período de inscrições.

# %% [markdown]
# **02. Uma turma de cinco alunos foi submetida a uma avaliação e a nota de cada um dos alunos é apresentada na tabela abaixo:**
#
# Nome do Aluno | Nota
# :------------:|:----:
# Wilfred       | 2
# Abbie         | 7
# Harry         | 5.5
# Julia         | 10
# Carrie        | 6.2
#
# (a) Crie uma Series com os valores da tabela acima.
# (b) Retorne o número de alunos que foram aprovados (considerando que a nota mínima para a aprovação é 7).
# (c) Qual foi a nota média da turma.
# (d) Obtenha o nome dos alunos que tiraram notas acima da média da turma.

# %% [markdown]
# **03. Crie um objeto DataFrame que contenha os dados da tabela abaixo, os quais se referem ao peso, altura e idade de cinco pessoas:**
#
# | Peso (kg) | Altura (cm) | Idade
# |:---------:|:-----------:|:-----:
# | 72        | 180         | 31
# | 80        | 170         | 21
# | 60        | 175         | 16
# | 90        | 174         | 28
# | 100       | 185         | 23
#
# Com base no DataFrame criado, realize o que pedido nos itens abaixo:
#
# (a) Visualize apenas os dados da coluna que contém a altura das pessoas.
# (b) Obtenha a idade média das pessoas.
# (c) Obtenha os dados das pessoas que estão abaixo da altura média.
# (d) Crie um nova coluna no DataFrame que contenha o IMC (Índice de Massa Corporal) de cada pessoa.
# (e) Remova a coluna que contém a idade das pessoas.
# (f) Salve esses dados do DataFrame em um arquivo csv.

# %% [markdown]
# **04. Carregue, em um objeto DataFrame, o arquivo CSV que você salvou no item (f) da questão anterior. Em seguida,**
#
# (a) Crie uma nova coluna que contenha o nome das pessoas (sinta-se à vontade para atribuir os nomes que preferir).
# (b) Defina a nova coluna criada (com os nomes) como o índice (`index`) do seu DataFrame.
# (c) Obtenha o nome das pessoas que são classificadas com Sobrepeso (IMC entre 25 e 29,9).

# %% [markdown]
# **05. Carregue, em um objeto DataFrame, o mesmo dataset que você salvou na Questão 3. Em seguida,**
#
# (a) Adicione uma nova coluna nesse DF chamada `Classificação`, que contenha a classificação de cada indivíduo, de acordo com o seu IMC. Para isso, consulte a tabela abaixo.
#
# | IMC               | Classificação   | Obesidade (grau) |
# |:-----------------:|:---------------:|:----------------:|
# | Menor que 18,5    | Magreza         |         0        |
# | Entre 18,5 e 24,9 | Normal          |         0        |
# | Entre 25,0 e 29,9 | Sobrepeso       |         I        |
# | Entre 30,0 e 39,9 | Obesidade       |        II        |
# | Maior que 40,0    | Obesidade Grave |        III       |
#
# (b) Salve em DataFrame no formato xlsx.
